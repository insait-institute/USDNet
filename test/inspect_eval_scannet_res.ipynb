# %%
import wandb
file = "/scratch/yang_miao/mask3d_mount/Mask3D_adapted/saved/validation_query_150_topk_500_dbscan_0.95"
# Initialize an offline run to load the file
run = wandb.Api().run(file)

# Access metrics and other run data
print(run.summary)  # This prints a summary of the run (e.g., final metrics)
print(run.config)   # This prints the hyperparameters and configuration
print(run.history())  # This prints the recorded history of metrics
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /scratch/yang_miao/micromamba/envs/softgroup/lib/python3.7/site-packages/wandb/apis/normalize.py in wrapper(*args, **kwargs)
#      40         try:
# ---> 41             return func(*args, **kwargs)
#      42         except requests.HTTPError as error:
#
# /scratch/yang_miao/micromamba/envs/softgroup/lib/python3.7/site-packages/wandb/apis/public/api.py in run(self, path)
#     859         if not self._runs.get(path):
# --> 860             self._runs[path] = public.Run(self.client, entity, project, run_id)
#     861         return self._runs[path]
#
# /scratch/yang_miao/micromamba/envs/softgroup/lib/python3.7/site-packages/wandb/apis/public/runs.py in __init__(self, client, entity, project, run_id, attrs, include_sweeps)
#     329
# --> 330         self.load(force=not _attrs)
#     331
#
# ...
